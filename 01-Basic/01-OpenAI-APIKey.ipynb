# %% [markdown]
# ## OpenAI API 키 발급 및 설정
#
# 1. OpenAI API 키 발급
#
# - [OpenAI API 키 발급방법](https://wikidocs.net/233342) 글을 참고해 주세요.
#
# 1. `.env` 파일 설정
#
# - 프로젝트 루트 디렉토리에 `.env` 파일을 생성합니다.
# - 파일에 API 키를 다음 형식으로 저장합니다:
#   `OPENAI_API_KEY` 에 발급받은 API KEY 를 입력합니다.
#
# - `.env` 파일에 발급한 API KEY 를 입력합니다.

# %%
# LangChain 업데이트
# !pip install -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt
# Out:
# Ignoring async-timeout: markers 'python_version >= "3.11" and python_full_version < "3.11.3"' don't match your environment
# Ignoring colorama: markers 'python_version >= "3.11" and python_version < "3.12" and (platform_system == "Windows" or os_name == "nt" or sys_platform == "win32")' don't match your environment
# Ignoring nvidia-cublas-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-cuda-cupti-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-cuda-nvrtc-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-cuda-runtime-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-cudnn-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-cufft-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-curand-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-cusolver-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-cusparse-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-nccl-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-nvjitlink-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-nvtx-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring pyreadline3: markers 'sys_platform == "win32" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring pywin32: markers 'python_version >= "3.11" and python_version < "3.12" and (sys_platform == "win32" or platform_system == "Windows") and (platform_python_implementation != "PyPy" or platform_system == "Windows")' don't match your environment
# Ignoring pywinpty: markers 'python_version >= "3.11" and python_version < "3.12" and os_name == "nt"' don't match your environment
# Ignoring triton: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version < "3.12" and python_version >= "3.11"' don't match your environment
# Ignoring watchdog: markers 'python_version >= "3.11" and python_version < "3.12" and platform_system != "Darwin"' don't match your environment
# Collecting aiohappyeyeballs==2.4.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 1))
#   Downloading aiohappyeyeballs-2.4.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiohttp==3.10.5 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 2))
#   Downloading aiohttp-3.10.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.5 kB)
# Collecting aiosignal==1.3.1 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 3))
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting altair==5.4.1 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 4))
#   Downloading altair-5.4.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: annotated-types==0.7.0 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 5)) (0.7.0)
# Collecting anthropic==0.34.1 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 6))
#   Downloading anthropic-0.34.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: antlr4-python3-runtime==4.9.3 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 7)) (4.9.3)
# Collecting anyio==4.4.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 8))
#   Downloading anyio-4.4.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: appdirs==1.4.4 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 9)) (1.4.4)
# Requirement already satisfied: appnope==0.1.4 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 10)) (0.1.4)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 11)) (21.2.0)
# Requirement already satisfied: argon2-cffi==23.1.0 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 12)) (23.1.0)
# Requirement already satisfied: arrow==1.3.0 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 13)) (1.3.0)
# Requirement already satisfied: arxiv==2.1.3 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 14)) (2.1.3)
# Requirement already satisfied: asgiref==3.8.1 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 15)) (3.8.1)
# Collecting asttokens==2.4.1 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 16))
#   Downloading asttokens-2.4.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: async-lru==2.0.4 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 17)) (2.0.4)
# Collecting attrs==24.2.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 19))
#   Downloading attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting babel==2.16.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 20))
#   Downloading babel-2.16.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: backoff==2.2.1 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 21)) (2.2.1)
# Collecting bcrypt==4.2.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 22))
#   Downloading bcrypt-4.2.0-cp39-abi3-macosx_10_12_universal2.whl.metadata (9.6 kB)
# Collecting beautifulsoup4==4.12.3 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 23))
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting bleach==6.1.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 24))
#   Downloading bleach-6.1.0-py3-none-any.whl.metadata (30 kB)
# Collecting blinker==1.8.2 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 25))
#   Downloading blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting boto3==1.35.10 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 26))
#   Downloading boto3-1.35.10-py3-none-any.whl.metadata (6.6 kB)
# Collecting botocore==1.35.10 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 27))
#   Downloading botocore-1.35.10-py3-none-any.whl.metadata (5.7 kB)
# Collecting build==1.2.1 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 28))
#   Downloading build-1.2.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting cachetools==5.5.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 29))
#   Downloading cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting certifi==2024.8.30 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 30))
#   Downloading certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Collecting cffi==1.17.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 31))
#   Downloading cffi-1.17.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Requirement already satisfied: chardet==5.2.0 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 32)) (5.2.0)
# Collecting charset-normalizer==3.3.2 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 33))
#   Downloading charset_normalizer-3.3.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (33 kB)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 34)) (0.7.3)
# Requirement already satisfied: chromadb==0.4.24 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 35)) (0.4.24)
# Collecting click==8.1.7 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 36))
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting cohere==5.9.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 37))
#   Downloading cohere-5.9.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: coloredlogs==15.0.1 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 39)) (15.0.1)
# Requirement already satisfied: comm==0.2.2 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 40)) (0.2.2)
# Collecting contourpy==1.3.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 41))
#   Downloading contourpy-1.3.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.4 kB)
# Collecting cryptography==43.0.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 42))
#   Downloading cryptography-43.0.0-cp39-abi3-macosx_10_9_universal2.whl.metadata (5.4 kB)
# Requirement already satisfied: cycler==0.12.1 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 43)) (0.12.1)
# Requirement already satisfied: dataclasses-json==0.6.7 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 44)) (0.6.7)
# Collecting datasets==2.21.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 45))
#   Downloading datasets-2.21.0-py3-none-any.whl.metadata (21 kB)
# Collecting debugpy==1.8.5 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 46))
#   Downloading debugpy-1.8.5-cp311-cp311-macosx_12_0_universal2.whl.metadata (1.1 kB)
# Collecting decorator==5.1.1 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 47))
#   Downloading decorator-5.1.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting deepl==1.18.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 48))
#   Downloading deepl-1.18.0-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: defusedxml==0.7.1 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 49)) (0.7.1)
# Collecting deprecated==1.2.14 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 50))
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: dill==0.3.8 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 51)) (0.3.8)
# Requirement already satisfied: dirtyjson==1.0.8 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 52)) (1.0.8)
# Requirement already satisfied: distro==1.9.0 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 53)) (1.9.0)
# Requirement already satisfied: docx2txt==0.8 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 54)) (0.8)
# Requirement already satisfied: ebooklib==0.18 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 55)) (0.18)
# Requirement already satisfied: effdet==0.4.1 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 56)) (0.4.1)
# Collecting elastic-transport==8.15.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 57))
#   Downloading elastic_transport-8.15.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting elasticsearch==8.15.0 (from elasticsearch[vectorstore-mmr]==8.15.0->-r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 58))
#   Downloading elasticsearch-8.15.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting emoji==2.12.1 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 59))
#   Downloading emoji-2.12.1-py3-none-any.whl.metadata (5.4 kB)
# Collecting environs==9.5.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 60))
#   Downloading environs-9.5.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting et-xmlfile==1.1.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 61))
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting executing==2.0.1 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 62))
#   Downloading executing-2.0.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting faiss-cpu==1.8.0.post1 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 63))
#   Downloading faiss_cpu-1.8.0.post1-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.7 kB)
# Collecting fastapi==0.112.2 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 64))
#   Downloading fastapi-0.112.2-py3-none-any.whl.metadata (27 kB)
# Collecting fastavro==1.9.5 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 65))
#   Downloading fastavro-1.9.5-cp311-cp311-macosx_10_9_universal2.whl.metadata (5.5 kB)
# Collecting fastjsonschema==2.20.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 66))
#   Downloading fastjsonschema-2.20.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: feedparser==6.0.11 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 67)) (6.0.11)
# Collecting filelock==3.15.4 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 68))
#   Downloading filelock-3.15.4-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: filetype==1.2.0 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 69)) (1.2.0)
# Collecting flashrank==0.2.9 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 70))
#   Downloading FlashRank-0.2.9-py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers==24.3.25 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 71))
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting fonttools==4.53.1 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 72))
#   Downloading fonttools-4.53.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (162 kB)
# Requirement already satisfied: fqdn==1.5.1 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 73)) (1.5.1)
# Collecting frozenlist==1.4.1 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 74))
#   Downloading frozenlist-1.4.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting fsspec==2024.6.1 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 75))
#   Downloading fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Collecting ftfy==6.2.3 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 77))
#   Downloading ftfy-6.2.3-py3-none-any.whl.metadata (7.8 kB)
# Collecting gitdb==4.0.11 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 78))
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Collecting gitpython==3.1.43 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 79))
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting google-ai-generativelanguage==0.6.6 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 80))
#   Downloading google_ai_generativelanguage-0.6.6-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: google-api-core==1.34.1 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 81)) (1.34.1)
# Collecting google-api-python-client==2.143.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 83))
#   Downloading google_api_python_client-2.143.0-py2.py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: google-auth-httplib2==0.2.0 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 84)) (0.2.0)
# Collecting google-auth==2.34.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 85))
#   Downloading google_auth-2.34.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-generativeai==0.7.2 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 86))
#   Downloading google_generativeai-0.7.2-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: google-search-results==2.4.2 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 87)) (2.4.2)
# Collecting googleapis-common-protos==1.65.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 88))
#   Downloading googleapis_common_protos-1.65.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: grandalf==0.8 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 89)) (0.8)
# Collecting greenlet==3.0.3 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 90))
#   Downloading greenlet-3.0.3-cp311-cp311-macosx_11_0_universal2.whl.metadata (3.8 kB)
# Requirement already satisfied: grpc-gateway-protoc-gen-openapiv2==0.1.0 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 91)) (0.1.0)
# Requirement already satisfied: grpcio-status==1.48.2 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 92)) (1.48.2)
# Collecting grpcio==1.66.1 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 93))
#   Downloading grpcio-1.66.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (3.9 kB)
# Requirement already satisfied: h11==0.14.0 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 94)) (0.14.0)
# Collecting httpcore==1.0.5 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 95))
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: httplib2==0.22.0 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 96)) (0.22.0)
# Collecting httptools==0.6.1 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 97))
#   Downloading httptools-0.6.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (3.6 kB)
# Requirement already satisfied: httpx-sse==0.4.0 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 98)) (0.4.0)
# Collecting httpx==0.27.2 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 99))
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting huggingface-hub==0.23.5 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 100))
#   Downloading huggingface_hub-0.23.5-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: humanfriendly==10.0 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 101)) (10.0)
# Collecting idna==3.8 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 102))
#   Downloading idna-3.8-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: importlib-metadata==8.4.0 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 103)) (8.4.0)
# Collecting importlib-resources==6.4.4 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 104))
#   Downloading importlib_resources-6.4.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: iopath==0.1.10 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 105)) (0.1.10)
# Requirement already satisfied: ipykernel==6.29.5 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 106)) (6.29.5)
# Collecting ipython==8.27.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 107))
#   Downloading ipython-8.27.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: ipywidgets==8.1.5 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 108)) (8.1.5)
# Requirement already satisfied: isoduration==20.11.0 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 109)) (20.11.0)
# Collecting jedi==0.19.1 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 110))
#   Downloading jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting jinja2==3.1.4 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 111))
#   Downloading jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting jiter==0.5.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 112))
#   Downloading jiter-0.5.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.6 kB)
# Collecting jmespath==1.0.1 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 113))
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: joblib==1.4.2 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 114)) (1.4.2)
# Collecting jpype1==1.5.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 115))
#   Downloading JPype1-1.5.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (4.9 kB)
# Collecting json5==0.9.25 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 116))
#   Downloading json5-0.9.25-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: jsonpatch==1.33 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 117)) (1.33)
# Requirement already satisfied: jsonpointer==3.0.0 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 118)) (3.0.0)
# Collecting jsonschema-specifications==2023.12.1 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 119))
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: jsonschema==4.23.0 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 120)) (4.23.0)
# Collecting jupyter-client==8.6.2 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 122))
#   Downloading jupyter_client-8.6.2-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: jupyter-console==6.6.3 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 123)) (6.6.3)
# Requirement already satisfied: jupyter-core==5.7.2 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 124)) (5.7.2)
# Collecting jupyter-events==0.10.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 125))
#   Downloading jupyter_events-0.10.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: jupyter-lsp==2.2.5 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 126)) (2.2.5)
# Requirement already satisfied: jupyter-server-terminals==0.5.3 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 127)) (0.5.3)
# Collecting jupyter-server==2.14.2 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 128))
#   Downloading jupyter_server-2.14.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: jupyter==1.1.1 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 129)) (1.1.1)
# Requirement already satisfied: jupyterlab-pygments==0.3.0 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 130)) (0.3.0)
# Requirement already satisfied: jupyterlab-server==2.27.3 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 131)) (2.27.3)
# Requirement already satisfied: jupyterlab-widgets==3.0.13 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 132)) (3.0.13)
# Collecting jupyterlab==4.2.5 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 133))
#   Downloading jupyterlab-4.2.5-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: kiwipiepy-model==0.17.0 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 134)) (0.17.0)
# Requirement already satisfied: kiwipiepy==0.17.1 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 135)) (0.17.1)
# Collecting kiwisolver==1.4.5 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 136))
#   Downloading kiwisolver-1.4.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Requirement already satisfied: konlpy==0.6.0 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 137)) (0.6.0)
# Collecting kubernetes==30.1.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 138))
#   Downloading kubernetes-30.1.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-anthropic==0.1.23 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 139))
#   Downloading langchain_anthropic-0.1.23-py3-none-any.whl.metadata (2.2 kB)
# Collecting langchain-chroma==0.1.3 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 140))
#   Downloading langchain_chroma-0.1.3-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-cohere==0.1.9 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 141))
#   Downloading langchain_cohere-0.1.9-py3-none-any.whl.metadata (6.6 kB)
# Collecting langchain-community==0.2.15 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 142))
#   Downloading langchain_community-0.2.15-py3-none-any.whl.metadata (2.7 kB)
# Collecting langchain-core==0.2.37 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 143))
#   Downloading langchain_core-0.2.37-py3-none-any.whl.metadata (6.2 kB)
# Collecting langchain-elasticsearch==0.2.2 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 144))
#   Downloading langchain_elasticsearch-0.2.2-py3-none-any.whl.metadata (8.3 kB)
# Collecting langchain-experimental==0.0.61 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 145))
#   Downloading langchain_experimental-0.0.61-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-google-genai==1.0.10 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 146))
#   Downloading langchain_google_genai-1.0.10-py3-none-any.whl.metadata (3.8 kB)
# Collecting langchain-huggingface==0.0.3 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 147))
#   Downloading langchain_huggingface-0.0.3-py3-none-any.whl.metadata (1.2 kB)
# Collecting langchain-milvus==0.1.4 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 148))
#   Downloading langchain_milvus-0.1.4-py3-none-any.whl.metadata (2.1 kB)
# Collecting langchain-openai==0.1.23 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 149))
#   Downloading langchain_openai-0.1.23-py3-none-any.whl.metadata (2.6 kB)
# Collecting langchain-teddynote==0.0.28 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 150))
#   Downloading langchain_teddynote-0.0.28-py3-none-any.whl.metadata (550 bytes)
# Collecting langchain-text-splitters==0.2.2 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 151))
#   Downloading langchain_text_splitters-0.2.2-py3-none-any.whl.metadata (2.1 kB)
# Collecting langchain-upstage==0.1.8 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 152))
#   Downloading langchain_upstage-0.1.8-py3-none-any.whl.metadata (3.4 kB)
# Collecting langchain==0.2.15 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 153))
#   Downloading langchain-0.2.15-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: langchainhub==0.1.21 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 154)) (0.1.21)
# Requirement already satisfied: langdetect==1.0.9 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 155)) (1.0.9)
# Collecting langgraph==0.0.69 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 156))
#   Downloading langgraph-0.0.69-py3-none-any.whl.metadata (11 kB)
# Collecting langsmith==0.1.108 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 157))
#   Downloading langsmith-0.1.108-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: lark==1.2.2 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 158)) (1.2.2)
# Requirement already satisfied: layoutparser==0.3.4 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from layoutparser[layoutmodels,tesseract]==0.3.4->-r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 159)) (0.3.4)
# Requirement already satisfied: llama-index-core==0.10.68.post1 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 160)) (0.10.68.post1)
# Requirement already satisfied: llama-index-readers-file==0.1.33 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 161)) (0.1.33)
# Requirement already satisfied: llama-parse==0.4.9 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 162)) (0.4.9)
# Collecting lxml==5.3.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 163))
#   Downloading lxml-5.3.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (3.8 kB)
# Collecting lz4==4.3.3 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 164))
#   Downloading lz4-4.3.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.7 kB)
# Requirement already satisfied: markdown-it-py==3.0.0 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 165)) (3.0.0)
# Requirement already satisfied: markdown==3.7 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 166)) (3.7)
# Collecting markupsafe==2.1.5 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 167))
#   Downloading MarkupSafe-2.1.5-cp311-cp311-macosx_10_9_universal2.whl.metadata (3.0 kB)
# Collecting marshmallow==3.22.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 168))
#   Downloading marshmallow-3.22.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: matplotlib-inline==0.1.7 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 169)) (0.1.7)
# Collecting matplotlib==3.9.2 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 170))
#   Downloading matplotlib-3.9.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: mdurl==0.1.2 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 171)) (0.1.2)
# Collecting milvus-lite==2.4.9 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 172))
#   Downloading milvus_lite-2.4.9-py3-none-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Collecting mistune==3.0.2 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 173))
#   Downloading mistune-3.0.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: mmh3==4.1.0 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 174)) (4.1.0)
# Requirement already satisfied: monotonic==1.6 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 175)) (1.6)
# Requirement already satisfied: mpmath==1.3.0 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 176)) (1.3.0)
# Requirement already satisfied: msg-parser==1.2.0 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 177)) (1.2.0)
# Collecting multidict==6.0.5 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 178))
#   Downloading multidict-6.0.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Requirement already satisfied: multiprocess==0.70.16 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 179)) (0.70.16)
# Requirement already satisfied: mypy-extensions==1.0.0 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 180)) (1.0.0)
# Collecting narwhals==1.6.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 181))
#   Downloading narwhals-1.6.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting nbclient==0.10.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 182))
#   Downloading nbclient-0.10.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting nbconvert==7.16.4 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 183))
#   Downloading nbconvert-7.16.4-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: nbformat==5.10.4 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 184)) (5.10.4)
# Requirement already satisfied: nest-asyncio==1.6.0 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 185)) (1.6.0)
# Collecting networkx==3.3 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 186))
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: nltk==3.9.1 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 187)) (3.9.1)
# Requirement already satisfied: notebook-shim==0.2.4 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 188)) (0.2.4)
# Collecting notebook==7.2.2 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 189))
#   Downloading notebook-7.2.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy==1.26.4 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 190)) (1.26.4)
# Requirement already satisfied: oauthlib==3.2.2 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 203)) (3.2.2)
# Requirement already satisfied: olefile==0.47 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 204)) (0.47)
# Requirement already satisfied: omegaconf==2.3.0 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 205)) (2.3.0)
# Requirement already satisfied: onnx==1.14.1 in /Users/minjeong/Library/Caches/pypoetry/virtualenvs/langchain-kr-szXyjQUn-py3.11/lib/python3.11/site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 206)) (1.14.1)
# Collecting onnxruntime==1.19.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 207))
#   Downloading onnxruntime-1.19.0-cp311-cp311-macosx_11_0_universal2.whl.metadata (4.3 kB)
# ...
#   Attempting uninstall: faiss-cpu
#     Found existing installation: faiss-cpu 1.10.0
#     Uninstalling faiss-cpu-1.10.0:
#       Successfully uninstalled faiss-cpu-1.10.0
#   Attempting uninstall: elastic-transport
#     Found existing installation: elastic-transport 8.17.0
#     Uninstalling elastic-transport-8.17.0:
#       Successfully uninstalled elastic-transport-8.17.0
#   Attempting uninstall: deprecated
#     Found existing installation: Deprecated 1.2.18
#     Uninstalling Deprecated-1.2.18:
#       Successfully uninstalled Deprecated-1.2.18
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 44.0.1
#     Uninstalling cryptography-44.0.1:
#       Successfully uninstalled cryptography-44.0.1
#   Attempting uninstall: build
#     Found existing installation: build 1.2.2.post1
#     Uninstalling build-1.2.2.post1:
#       Successfully uninstalled build-1.2.2.post1
#   Attempting uninstall: bleach
#     Found existing installation: bleach 6.2.0
#     Uninstalling bleach-6.2.0:
#       Successfully uninstalled bleach-6.2.0
#   Attempting uninstall: asttokens
#     Found existing installation: asttokens 3.0.0
#     Uninstalling asttokens-3.0.0:
#       Successfully uninstalled asttokens-3.0.0
#   Attempting uninstall: anyio
#     Found existing installation: anyio 4.8.0
#     Uninstalling anyio-4.8.0:
#       Successfully uninstalled anyio-4.8.0
#   Attempting uninstall: aiosignal
#     Found existing installation: aiosignal 1.3.2
#     Uninstalling aiosignal-1.3.2:
#       Successfully uninstalled aiosignal-1.3.2
#   Attempting uninstall: watchfiles
#     Found existing installation: watchfiles 1.0.4
#     Uninstalling watchfiles-1.0.4:
#       Successfully uninstalled watchfiles-1.0.4
#   Attempting uninstall: typer
#     Found existing installation: typer 0.15.1
#     Uninstalling typer-0.15.1:
#       Successfully uninstalled typer-0.15.1
#   Attempting uninstall: starlette
#     Found existing installation: starlette 0.45.3
#     Uninstalling starlette-0.45.3:
#       Successfully uninstalled starlette-0.45.3
#   Attempting uninstall: rapidocr-onnxruntime
#     Found existing installation: rapidocr-onnxruntime 1.4.4
#     Uninstalling rapidocr-onnxruntime-1.4.4:
#       Successfully uninstalled rapidocr-onnxruntime-1.4.4
#   Attempting uninstall: pymupdf4llm
#     Found existing installation: pymupdf4llm 0.0.17
#     Uninstalling pymupdf4llm-0.0.17:
#       Successfully uninstalled pymupdf4llm-0.0.17
#   Attempting uninstall: posthog
#     Found existing installation: posthog 3.15.1
#     Uninstalling posthog-3.15.1:
#       Successfully uninstalled posthog-3.15.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.3
#     Uninstalling pandas-2.2.3:
#       Successfully uninstalled pandas-2.2.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter_client 8.6.3
#     Uninstalling jupyter_client-8.6.3:
#       Successfully uninstalled jupyter_client-8.6.3
#   Attempting uninstall: jsonschema-specifications
#     Found existing installation: jsonschema-specifications 2024.10.1
#     Uninstalling jsonschema-specifications-2024.10.1:
#       Successfully uninstalled jsonschema-specifications-2024.10.1
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.25.2
#     Uninstalling huggingface-hub-0.25.2:
#       Successfully uninstalled huggingface-hub-0.25.2
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.38.0
#     Uninstalling google-auth-2.38.0:
#       Successfully uninstalled google-auth-2.38.0
#   Attempting uninstall: gitpython
#     Found existing installation: GitPython 3.1.44
#     Uninstalling GitPython-3.1.44:
#       Successfully uninstalled GitPython-3.1.44
#   Attempting uninstall: elasticsearch
#     Found existing installation: elasticsearch 8.17.1
#     Uninstalling elasticsearch-8.17.1:
#       Successfully uninstalled elasticsearch-8.17.1
#   Attempting uninstall: deepl
#     Found existing installation: deepl 1.21.0
#     Uninstalling deepl-1.21.0:
#       Successfully uninstalled deepl-1.21.0
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.11.12
#     Uninstalling aiohttp-3.11.12:
#       Successfully uninstalled aiohttp-3.11.12
#   Attempting uninstall: pymilvus
#     Found existing installation: pymilvus 2.5.4
#     Uninstalling pymilvus-2.5.4:
#       Successfully uninstalled pymilvus-2.5.4
#   Attempting uninstall: pdfplumber
#     Found existing installation: pdfplumber 0.11.5
#     Uninstalling pdfplumber-0.11.5:
#       Successfully uninstalled pdfplumber-0.11.5
#   Attempting uninstall: openai
#     Found existing installation: openai 1.64.0
#     Uninstalling openai-1.64.0:
#       Successfully uninstalled openai-1.64.0
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.1.147
#     Uninstalling langsmith-0.1.147:
#       Successfully uninstalled langsmith-0.1.147
#   Attempting uninstall: kubernetes
#     Found existing installation: kubernetes 32.0.1
#     Uninstalling kubernetes-32.0.1:
#       Successfully uninstalled kubernetes-32.0.1
#   Attempting uninstall: ipython
#     Found existing installation: ipython 8.32.0
#     Uninstalling ipython-8.32.0:
#       Successfully uninstalled ipython-8.32.0
#   Attempting uninstall: fastapi
#     Found existing installation: fastapi 0.115.8
#     Uninstalling fastapi-0.115.8:
#       Successfully uninstalled fastapi-0.115.8
#   Attempting uninstall: timm
#     Found existing installation: timm 1.0.15
#     Uninstalling timm-1.0.15:
#       Successfully uninstalled timm-1.0.15
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.37
#     Uninstalling langchain-core-0.3.37:
#       Successfully uninstalled langchain-core-0.3.37
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 2.161.0
#     Uninstalling google-api-python-client-2.161.0:
#       Successfully uninstalled google-api-python-client-2.161.0
#   Attempting uninstall: flashrank
#     Found existing installation: FlashRank 0.2.10
#     Uninstalling FlashRank-0.2.10:
#       Successfully uninstalled FlashRank-0.2.10
#   Attempting uninstall: datasets
#     Found existing installation: datasets 3.3.2
#     Uninstalling datasets-3.3.2:
#       Successfully uninstalled datasets-3.3.2
#   Attempting uninstall: anthropic
#     Found existing installation: anthropic 0.46.0
#     Uninstalling anthropic-0.46.0:
#       Successfully uninstalled anthropic-0.46.0
#   Attempting uninstall: altair
#     Found existing installation: altair 5.5.0
#     Uninstalling altair-5.5.0:
#       Successfully uninstalled altair-5.5.0
#   Attempting uninstall: streamlit
#     Found existing installation: streamlit 1.42.2
#     Uninstalling streamlit-1.42.2:
#       Successfully uninstalled streamlit-1.42.2
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 3.4.1
#     Uninstalling sentence-transformers-3.4.1:
#       Successfully uninstalled sentence-transformers-3.4.1
#   Attempting uninstall: open-clip-torch
#     Found existing installation: open_clip_torch 2.30.0
#     Uninstalling open_clip_torch-2.30.0:
#       Successfully uninstalled open_clip_torch-2.30.0
#   Attempting uninstall: nbclient
#     Found existing installation: nbclient 0.10.2
#     Uninstalling nbclient-0.10.2:
#       Successfully uninstalled nbclient-0.10.2
#   Attempting uninstall: langgraph
#     Found existing installation: langgraph 0.2.74
#     Uninstalling langgraph-0.2.74:
#       Successfully uninstalled langgraph-0.2.74
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.3.6
#     Uninstalling langchain-text-splitters-0.3.6:
#       Successfully uninstalled langchain-text-splitters-0.3.6
#   Attempting uninstall: langchain-openai
#     Found existing installation: langchain-openai 0.2.14
#     Uninstalling langchain-openai-0.2.14:
#       Successfully uninstalled langchain-openai-0.2.14
#   Attempting uninstall: langchain-milvus
#     Found existing installation: langchain-milvus 0.1.8
#     Uninstalling langchain-milvus-0.1.8:
#       Successfully uninstalled langchain-milvus-0.1.8
#   Attempting uninstall: langchain-elasticsearch
#     Found existing installation: langchain-elasticsearch 0.3.2
#     Uninstalling langchain-elasticsearch-0.3.2:
#       Successfully uninstalled langchain-elasticsearch-0.3.2
#   Attempting uninstall: langchain-anthropic
#     Found existing installation: langchain-anthropic 0.2.4
#     Uninstalling langchain-anthropic-0.2.4:
#       Successfully uninstalled langchain-anthropic-0.2.4
#   Attempting uninstall: jupyter-events
#     Found existing installation: jupyter-events 0.12.0
#     Uninstalling jupyter-events-0.12.0:
#       Successfully uninstalled jupyter-events-0.12.0
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.6.15
#     Uninstalling google-ai-generativelanguage-0.6.15:
#       Successfully uninstalled google-ai-generativelanguage-0.6.15
#   Attempting uninstall: cohere
#     Found existing installation: cohere 5.13.12
#     Uninstalling cohere-5.13.12:
#       Successfully uninstalled cohere-5.13.12
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 7.16.6
#     Uninstalling nbconvert-7.16.6:
#       Successfully uninstalled nbconvert-7.16.6
#   Attempting uninstall: langchain-upstage
#     Found existing installation: langchain-upstage 0.3.0
#     Uninstalling langchain-upstage-0.3.0:
#       Successfully uninstalled langchain-upstage-0.3.0
#   Attempting uninstall: langchain-huggingface
#     Found existing installation: langchain-huggingface 0.1.2
#     Uninstalling langchain-huggingface-0.1.2:
#       Successfully uninstalled langchain-huggingface-0.1.2
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.19
#     Uninstalling langchain-0.3.19:
#       Successfully uninstalled langchain-0.3.19
#   Attempting uninstall: google-generativeai
#     Found existing installation: google-generativeai 0.8.4
#     Uninstalling google-generativeai-0.8.4:
#       Successfully uninstalled google-generativeai-0.8.4
#   Attempting uninstall: langchain-teddynote
#     Found existing installation: langchain-teddynote 0.3.42
#     Uninstalling langchain-teddynote-0.3.42:
#       Successfully uninstalled langchain-teddynote-0.3.42
#   Attempting uninstall: langchain-google-genai
#     Found existing installation: langchain-google-genai 2.0.10
#     Uninstalling langchain-google-genai-2.0.10:
#       Successfully uninstalled langchain-google-genai-2.0.10
#   Attempting uninstall: langchain-community
#     Found existing installation: langchain-community 0.3.18
#     Uninstalling langchain-community-0.3.18:
#       Successfully uninstalled langchain-community-0.3.18
#   Attempting uninstall: langchain-chroma
#     Found existing installation: langchain-chroma 0.1.4
#     Uninstalling langchain-chroma-0.1.4:
#       Successfully uninstalled langchain-chroma-0.1.4
#   Attempting uninstall: jupyter-server
#     Found existing installation: jupyter_server 2.15.0
#     Uninstalling jupyter_server-2.15.0:
#       Successfully uninstalled jupyter_server-2.15.0
#   Attempting uninstall: ragas
#     Found existing installation: ragas 0.1.19
#     Uninstalling ragas-0.1.19:
#       Successfully uninstalled ragas-0.1.19
#   Attempting uninstall: langchain-experimental
#     Found existing installation: langchain-experimental 0.3.4
#     Uninstalling langchain-experimental-0.3.4:
#       Successfully uninstalled langchain-experimental-0.3.4
#   Attempting uninstall: langchain-cohere
#     Found existing installation: langchain-cohere 0.3.5
#     Uninstalling langchain-cohere-0.3.5:
#       Successfully uninstalled langchain-cohere-0.3.5
#   Attempting uninstall: jupyterlab
#     Found existing installation: jupyterlab 4.3.5
#     Uninstalling jupyterlab-4.3.5:
#       Successfully uninstalled jupyterlab-4.3.5
#   Attempting uninstall: notebook
#     Found existing installation: notebook 7.3.2
#     Uninstalling notebook-7.3.2:
#       Successfully uninstalled notebook-7.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langgraph-checkpoint 2.0.16 requires langchain-core<0.4,>=0.2.38, but you have langchain-core 0.2.37 which is incompatible.
# ollama 0.4.7 requires pydantic<3.0.0,>=2.9.0, but you have pydantic 2.9.0b2 which is incompatible.
# langchain-ollama 0.2.3 requires langchain-core<0.4.0,>=0.3.33, but you have langchain-core 0.2.37 which is incompatible.
# Successfully installed aiohappyeyeballs-2.4.0 aiohttp-3.10.5 aiosignal-1.3.1 altair-5.4.1 anthropic-0.34.1 anyio-4.4.0 asttokens-2.4.1 attrs-24.2.0 babel-2.16.0 bcrypt-4.2.0 beautifulsoup4-4.12.3 bleach-6.1.0 blinker-1.8.2 boto3-1.35.10 botocore-1.35.10 build-1.2.1 cachetools-5.5.0 certifi-2024.8.30 cffi-1.17.0 charset-normalizer-3.3.2 click-8.1.7 cohere-5.9.0 contourpy-1.3.0 cryptography-43.0.0 datasets-2.21.0 debugpy-1.8.5 decorator-5.1.1 deepl-1.18.0 deprecated-1.2.14 elastic-transport-8.15.0 elasticsearch-8.15.0 emoji-2.12.1 environs-9.5.0 et-xmlfile-1.1.0 executing-2.0.1 faiss-cpu-1.8.0.post1 fastapi-0.112.2 fastavro-1.9.5 fastjsonschema-2.20.0 filelock-3.15.4 flashrank-0.2.9 flatbuffers-24.3.25 fonttools-4.53.1 frozenlist-1.4.1 fsspec-2024.6.1 ftfy-6.2.3 gitdb-4.0.11 gitpython-3.1.43 google-ai-generativelanguage-0.6.6 google-api-python-client-2.143.0 google-auth-2.34.0 google-generativeai-0.7.2 googleapis-common-protos-1.65.0 greenlet-3.0.3 grpcio-1.66.1 httpcore-1.0.5 httptools-0.6.1 httpx-0.27.2 huggingface-hub-0.23.5 idna-3.8 importlib-resources-6.4.4 ipython-8.27.0 jedi-0.19.1 jinja2-3.1.4 jiter-0.5.0 jmespath-1.0.1 jpype1-1.5.0 json5-0.9.25 jsonschema-specifications-2023.12.1 jupyter-client-8.6.2 jupyter-events-0.10.0 jupyter-server-2.14.2 jupyterlab-4.2.5 kiwisolver-1.4.5 kubernetes-30.1.0 langchain-0.2.15 langchain-anthropic-0.1.23 langchain-chroma-0.1.3 langchain-cohere-0.1.9 langchain-community-0.2.15 langchain-core-0.2.37 langchain-elasticsearch-0.2.2 langchain-experimental-0.0.61 langchain-google-genai-1.0.10 langchain-huggingface-0.0.3 langchain-milvus-0.1.4 langchain-openai-0.1.23 langchain-teddynote-0.0.28 langchain-text-splitters-0.2.2 langchain-upstage-0.1.8 langgraph-0.0.69 langsmith-0.1.108 lxml-5.3.0 lz4-4.3.3 markupsafe-2.1.5 marshmallow-3.22.0 matplotlib-3.9.2 milvus-lite-2.4.9 mistune-3.0.2 multidict-6.0.5 narwhals-1.6.0 nbclient-0.10.0 nbconvert-7.16.4 networkx-3.3 notebook-7.2.2 onnxruntime-1.19.0 open-clip-torch-2.26.1 openai-1.43.0 opencv-python-4.10.0.84 orjson-3.10.7 packaging-24.1 pandas-2.2.2 parameterized-0.9.0 pdfplumber-0.11.4 platformdirs-4.2.2 portalocker-2.10.1 posthog-3.6.0 prometheus-client-0.20.0 prompt-toolkit-3.0.47 proto-plus-1.24.0 psutil-6.0.0 pulsar-client-3.5.0 pyarrow-17.0.0 pyasn1-0.6.0 pyasn1-modules-0.4.0 pyclipper-1.3.0.post5 pydantic-2.9.0b2 pydantic-core-2.23.1 pygments-2.18.0 pymilvus-2.4.6 pymupdf-1.24.9 pymupdf4llm-0.0.12 pymupdfb-1.24.9 pypandoc-1.13 pyparsing-3.1.4 pypdfium2-4.30.0 pyproject-hooks-1.1.0 python-iso639-2024.4.27 python-json-logger-2.0.7 python-multipart-0.0.9 pytz-2024.1 pyzmq-26.2.0 ragas-0.1.15 rapidfuzz-3.9.6 rapidocr-onnxruntime-1.3.24 redis-5.0.8 referencing-0.35.1 regex-2024.7.24 rich-13.8.0 rpds-py-0.20.0 s3transfer-0.10.2 safetensors-0.4.4 scikit-learn-1.5.1 scipy-1.14.1 sentence-transformers-3.0.1 setuptools-74.0.0 shapely-2.0.6 simsimd-5.0.1 six-1.16.0 smmap-5.0.1 sqlalchemy-2.0.32 starlette-0.38.2 streamlit-1.38.0 sympy-1.13.2 timm-1.0.9 tinycss2-1.3.0 tornado-6.4.1 tqdm-4.66.5 typer-0.12.5 types-python-dateutil-2.9.0.20240821 types-requests-2.32.0.20240712 tzdata-2024.1 urllib3-2.2.2 uvicorn-0.30.6 uvloop-0.20.0 watchfiles-0.24.0 webcolors-24.8.0 websockets-13.0.1 wrapt-1.16.0 xlsxwriter-3.2.0 yarl-1.9.6 zipp-3.20.1

# %%
# API KEY를 환경변수로 관리하기 위한 설정 파일
from dotenv import load_dotenv

# API KEY 정보로드
load_dotenv()
# Out:
# True

# %% [markdown]
# API Key 가 잘 설정되었는지 확인합니다.

# %%
import os

print(f"[API KEY]\n{os.environ['OPENAI_API_KEY'][:-15]}" + "*" * 15)
# Out:
# [API KEY]
# ***************

# %% [markdown]
# 설치된 LangChain 버전을 확인합니다.

# %%
from importlib.metadata import version

print("[LangChain 관련 패키지 버전]")
for package_name in [
    "langchain",
    "langchain-core",
    "langchain-experimental",
    "langchain-community",
    "langchain-openai",
    "langchain-teddynote",
    "langchain-huggingface",
    "langchain-google-genai",
    "langchain-anthropic",
    "langchain-cohere",
    "langchain-chroma",
    "langchain-elasticsearch",
    "langchain-upstage",
    "langchain-cohere",
    "langchain-milvus",
    "langchain-text-splitters",
]:
    try:
        package_version = version(package_name)
        print(f"{package_name}: {package_version}")
    except ImportError:
        print(f"{package_name}: 설치되지 않음")
# Out:
# [LangChain 관련 패키지 버전]
# langchain: 0.2.15
# langchain-core: 0.2.37
# langchain-experimental: 0.0.61
# langchain-community: 0.2.15
# langchain-openai: 0.1.23
# langchain-teddynote: 0.0.28
# langchain-huggingface: 0.0.3
# langchain-google-genai: 1.0.10
# langchain-anthropic: 0.1.23
# langchain-cohere: 0.1.9
# langchain-chroma: 0.1.3
# langchain-elasticsearch: 0.2.2
# langchain-upstage: 0.1.8
# langchain-cohere: 0.1.9
# langchain-milvus: 0.1.4
# langchain-text-splitters: 0.2.2
